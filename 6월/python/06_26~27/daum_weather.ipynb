# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 다음 사이트에서 원하는 지역 날씨 정보 크롤링 하기
import requests
from bs4 import BeautifulSoup

base_url = "https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q="
location = input()
search_query = location + "+날씨"

url = base_url + search_query
# url_1 = f'https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q={location}+날씨'

html_weather = requests.get(url).text
soup_weather = BeautifulSoup(html_weather, 'lxml')

# %%
# select에서 .은 하위 클래스를 뜻한다
txt_temp = soup_weather.select_one('strong.txt_temp').text
txt_weather = soup_weather.select_one('span.txt_weather').text

# %%
#dl의 dl_weather 안에 있는 dd의 정보
dl_weather = soup_weather.select('dl.dl_weather dd')

# 변수 하나씩 넣어주는 방식. for 문에서 append 방식을 사용해도 된다.
[wind_speed, humidity, pm10] = [x.text for x in dl_weather]
# Out:
# '0.2m/s'

# %%
print(f'현재 풍속 : {wind_speed}\n현재 습도 : {humidity}\n미세번지 : {pm10}')
# Out:
# 현재 풍속 : 0.2m/s
# 현재 습도 : 60%
# 미세번지 : 보통 (44㎍/㎥)

# %%
for value in dl_weather:
    print(value.text)
# Out:
# 0.2m/s
# 60%
# 보통 (44㎍/㎥)

# %%
soup_weather
# Out:
# <!DOCTYPE html>
# <html lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="text/html;charset=utf-8" http-equiv="content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="off" name="autocomplete"/>
# <meta content="always" name="referrer"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="대전 날씨 – Daum 검색" property="og:title"/>
# <meta content="https://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=%EB%8C%80%EC%A0%84+%EB%82%A0%EC%94%A8" property="og:url"/>
# <meta content="Daum 검색에서 대전 날씨에 대한 최신정보를 찾아보세요." property="og:description"/>
# <meta content="https://search1.daumcdn.net/search/statics/common/img/og_search_20240403.png" property="og:image"/>
# <meta content="다음검색" property="og:site_name"/>
# <title>대전 날씨 – Daum 검색</title>
# ...
