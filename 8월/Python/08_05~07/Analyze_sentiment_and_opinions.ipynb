# %%
# This example requires environment variables named "LANGUAGE_KEY" and "LANGUAGE_ENDPOINT"
language_key = '38cd2eda0b6b419e8f22896af727c0f6'
language_endpoint = 'https://owner-1507-ailang.cognitiveservices.azure.com/'

from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential

# Authenticate the client using your key and endpoint 
def authenticate_client():
    ta_credential = AzureKeyCredential(language_key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=language_endpoint, 
            credential=ta_credential)
    return text_analytics_client

client = authenticate_client()

# Example method for detecting sentiment and opinions in text 
def sentiment_analysis_with_opinion_mining_example(client):

    documents = [
        "이렇게 주인공이 걱정이 안되는영화는 첨이네요..",
        "윤계상은 이제 배우라 불러도 손색없을듯! 악역 진짜 잘함 어찌나 몰입했던지 보는 중간에 나쁜놈이라 욕나옴. 시작은 마동석이 끝은 윤계상이 다함",
        "졸라잼있음 한번보세요",
        "시원하다 화끈하다 마블리를 느껴라",
        " 매력 넘치는 캐릭터가 많아 보기 좋네요",
        "ㅋㅋ잔인한것도 있지만 재밌게 잘 봤음"
    ]

    result = client.analyze_sentiment(documents, show_opinion_mining=True, language='ko')
    doc_result = [doc for doc in result if not doc.is_error]

    positive_reviews = [doc for doc in doc_result if doc.sentiment == "positive"]
    negative_reviews = [doc for doc in doc_result if doc.sentiment == "negative"]

    positive_mined_opinions = []
    mixed_mined_opinions = []
    negative_mined_opinions = []

    for document in doc_result:
        print("Document Sentiment: {}".format(document.sentiment))
        print("Overall scores: positive={0:.2f}; neutral={1:.2f}; negative={2:.2f} \n".format(
            document.confidence_scores.positive,
            document.confidence_scores.neutral,
            document.confidence_scores.negative,
        ))
        for sentence in document.sentences:
            print("Sentence: {}".format(sentence.text))
            print("Sentence sentiment: {}".format(sentence.sentiment))
            print("Sentence score:\nPositive={0:.2f}\nNeutral={1:.2f}\nNegative={2:.2f}\n".format(
                sentence.confidence_scores.positive,
                sentence.confidence_scores.neutral,
                sentence.confidence_scores.negative,
            ))
            for mined_opinion in sentence.mined_opinions:
                target = mined_opinion.target
                print("......'{}' target '{}'".format(target.sentiment, target.text))
                print("......Target score:\n......Positive={0:.2f}\n......Negative={1:.2f}\n".format(
                    target.confidence_scores.positive,
                    target.confidence_scores.negative,
                ))
                for assessment in mined_opinion.assessments:
                    print("......'{}' assessment '{}'".format(assessment.sentiment, assessment.text))
                    print("......Assessment score:\n......Positive={0:.2f}\n......Negative={1:.2f}\n".format(
                        assessment.confidence_scores.positive,
                        assessment.confidence_scores.negative,
                    ))
            print("\n")
        print("\n")
          
sentiment_analysis_with_opinion_mining_example(client)
# Out:
# Document Sentiment: negative
# Overall scores: positive=0.36; neutral=0.01; negative=0.63
#
# Sentence: 이렇게 주인공이 걱정이 안되는영화는 첨이네요..
# Sentence sentiment: negative
# Sentence score:
# Positive=0.36
# Neutral=0.01
# Negative=0.63
#
#
#
#
#
# Document Sentiment: negative
# Overall scores: positive=0.03; neutral=0.00; negative=0.97
#
# Sentence: 윤계상은 이제 배우라 불러도 손색없을듯!
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.38
# Neutral=0.51
# Negative=0.11
#
#
#
# Sentence: 악역 진짜 잘함 어찌나 몰입했던지 보는 중간에 나쁜놈이라 욕나옴.
# Sentence sentiment: negative
# Sentence score:
# Positive=0.03
# Neutral=0.00
# Negative=0.97
#
#
#
# Sentence: 시작은 마동석이 끝은 윤계상이 다함
# Sentence sentiment: neutral
# Sentence score:
# Positive=0.05
# Neutral=0.91
# Negative=0.04
#
# ......'negative' target '윤계상'
# ......Target score:
# ......Positive=0.06
# ......Negative=0.94
#
# ......'negative' assessment '함'
# ......Assessment score:
# ......Positive=0.08
# ......Negative=0.92
#
# ......'negative' assessment '다함'
# ......Assessment score:
# ......Positive=0.05
# ......Negative=0.95
#
#
#
#
#
# Document Sentiment: positive
# Overall scores: positive=0.79; neutral=0.20; negative=0.01
#
# Sentence: 졸라잼있음 한번보세요
# Sentence sentiment: positive
# Sentence score:
# Positive=0.79
# Neutral=0.20
# Negative=0.01
#
#
#
#
#
# Document Sentiment: positive
# Overall scores: positive=0.99; neutral=0.01; negative=0.00
#
# Sentence: 시원하다 화끈하다 마블리를 느껴라
# Sentence sentiment: positive
# Sentence score:
# Positive=0.99
# Neutral=0.01
# Negative=0.00
#
#
#
#
#
# Document Sentiment: positive
# Overall scores: positive=1.00; neutral=0.00; negative=0.00
#
# Sentence:  매력 넘치는 캐릭터가 많아 보기 좋네요
# Sentence sentiment: positive
# Sentence score:
# Positive=1.00
# Neutral=0.00
# Negative=0.00
#
# ......'positive' target '캐릭터'
# ......Target score:
# ......Positive=0.99
# ......Negative=0.01
#
# ......'positive' assessment '매력 넘치는'
# ......Assessment score:
# ......Positive=0.99
# ......Negative=0.01
#
#
#
#
#
# Document Sentiment: positive
# Overall scores: positive=1.00; neutral=0.00; negative=0.00
#
# Sentence: ㅋㅋ잔인한것도 있지만 재밌게 잘 봤음
# Sentence sentiment: positive
# Sentence score:
# Positive=1.00
# Neutral=0.00
# Negative=0.00
