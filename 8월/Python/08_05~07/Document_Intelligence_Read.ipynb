# %%
"""
This code sample shows Prebuilt Read operations with the Azure Form Recognizer client library. 
The async versions of the samples require Python 3.6 or later.

To learn more, please visit the documentation - Quickstart: Document Intelligence (formerly Form Recognizer) SDKs
https://learn.microsoft.com/azure/ai-services/document-intelligence/quickstarts/get-started-sdks-rest-api?pivots=programming-language-python
"""

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""
endpoint = "https://1507docuintelli.cognitiveservices.azure.com/"
key = "2ca4c2433352430f906ee0c520ca69bf"

def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

def analyze_read():
    # sample document
    formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-layout.pdf"

    document_analysis_client = DocumentAnalysisClient(
        endpoint=endpoint, credential=AzureKeyCredential(key)
    )
    
    poller = document_analysis_client.begin_analyze_document_from_url(
            "prebuilt-read", formUrl)
    result = poller.result()

    print ("Document contains content: ", result.content)
    
    for idx, style in enumerate(result.styles):
        print(
            "Document contains {} content".format(
                "handwritten" if style.is_handwritten else "no handwritten"
            )
        )

    for page in result.pages:
        print("----Analyzing Read from page #{}----".format(page.page_number))
        print(
            "Page has width: {} and height: {}, measured with unit: {}".format(
                page.width, page.height, page.unit
            )
        )

        for line_idx, line in enumerate(page.lines):
            print(
                "...Line # {} has text content '{}' within bounding box '{}'".format(
                    line_idx,
                    line.content,
                    format_bounding_box(line.polygon),
                )
            )

        for word in page.words:
            print(
                "...Word '{}' has a confidence of {}".format(
                    word.content, word.confidence
                )
            )

    print("----------------------------------------")


if __name__ == "__main__":
    analyze_read()

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

endpoint = "https://1507docuintelli.cognitiveservices.azure.com/"
key = "2ca4c2433352430f906ee0c520ca69bf"

def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

def analyze_read():
    # Local file path
    formPath = "./File/korecipe.png"

    document_analysis_client = DocumentAnalysisClient(
        endpoint=endpoint, credential=AzureKeyCredential(key)
    )
    
    with open(formPath, "rb") as fd:
        poller = document_analysis_client.begin_analyze_document(
                "prebuilt-read", fd)
        result = poller.result()

    print("Document contains content: ", result.content)
    
    for idx, style in enumerate(result.styles):
        print(
            "Document contains {} content".format(
                "handwritten" if style.is_handwritten else "no handwritten"
            )
        )

    for page in result.pages:
        print("----Analyzing Read from page #{}----".format(page.page_number))
        print(
            "Page has width: {} and height: {}, measured with unit: {}".format(
                page.width, page.height, page.unit
            )
        )

        for line_idx, line in enumerate(page.lines):
            print(
                "...Line # {} has text content '{}' within bounding box '{}'".format(
                    line_idx,
                    line.content,
                    format_bounding_box(line.polygon),
                )
            )

        for word in page.words:
            print(
                "...Word '{}' has a confidence of {}".format(
                    word.content, word.confidence
                )
            )

    print("----------------------------------------")

if __name__ == "__main__":
    analyze_read()
# Out:
# Document contains content:  STARBUCKS
# 현금(소득공제) 화성시청점 T:1522-3232 경기 화성 시청로 113 대표 : 충데이비드호선 201-81-21515 [매장#3794. POS 01] 2021-08-11 13:02:33
# 주문번호 A-01
# T)콜드 브루 4,500 1 4,500
# I-T) 아메리카노 4. 100 2 8,200
# 합계
# 12,700
# 결제금액
# 12, 700
# (부가세포함)
# (1, 154)
# 카카오페이
# 12, 700
# 결제 수단 :
# 카카오페이머니(머니)
# 바코드 번호 : 281006 ************** 0800
# 승인 번호 :
# 29508878
# 현금영수증 발급 500
# 010 -****- 2995
# 승인번호: 177263830 현금영수증 문의 : 126-1-1
# 결제수단 변경은 구입하신 매장에서 가능하며, 반드시 구매 영수증과 원거래 결제수단을 지참하셔야 합니다. (변경 가능 기간 : ~ 2021-08-25)
# www. starbucks. co. kr
# *20130482101130749* 본 영수증은 BPA Free 종이를 사용합니다.
# 고객요청에의해 일회용컵이 제공되었습니다
# Document contains handwritten content
# ----Analyzing Read from page #1----
# Page has width: 420.0 and height: 560.0, measured with unit: pixel
# ...Line # 0 has text content 'STARBUCKS' within bounding box '[109.0, 61.0], [272.0, 59.0], [272.0, 82.0], [109.0, 84.0]'
# ...Line # 1 has text content '현금(소득공제)' within bounding box '[121.0, 93.0], [260.0, 90.0], [261.0, 105.0], [121.0, 108.0]'
# ...Line # 2 has text content '화성시청점' within bounding box '[91.0, 105.0], [143.0, 105.0], [143.0, 115.0], [91.0, 115.0]'
# ...Line # 3 has text content 'T:1522-3232' within bounding box '[234.0, 101.0], [293.0, 98.0], [293.0, 110.0], [234.0, 113.0]'
# ...Line # 4 has text content '경기 화성 시청로 113' within bounding box '[90.0, 112.0], [192.0, 114.0], [192.0, 126.0], [90.0, 124.0]'
# ...Line # 5 has text content '대표 : 충데이비드호선' within bounding box '[90.0, 123.0], [186.0, 124.0], [186.0, 136.0], [90.0, 134.0]'
# ...Line # 6 has text content '201-81-21515' within bounding box '[229.0, 122.0], [293.0, 118.0], [293.0, 130.0], [230.0, 133.0]'
# ...Line # 7 has text content '[매장#3794. POS 01] 2021-08-11 13:02:33' within bounding box '[90.0, 133.0], [293.0, 129.0], [294.0, 141.0], [91.0, 145.0]'
# ...Line # 8 has text content '주문번호 A-01' within bounding box '[121.0, 153.0], [249.0, 152.0], [249.0, 174.0], [121.0, 176.0]'
# ...Line # 9 has text content 'T)콜드 브루' within bounding box '[90.0, 182.0], [147.0, 182.0], [147.0, 192.0], [90.0, 192.0]'
# ...Line # 10 has text content '4,500' within bounding box '[197.0, 182.0], [223.0, 182.0], [223.0, 191.0], [197.0, 191.0]'
# ...Line # 11 has text content '1' within bounding box '[235.0, 181.0], [242.0, 181.0], [243.0, 191.0], [235.0, 191.0]'
# ...Line # 12 has text content '4,500' within bounding box '[266.0, 179.0], [293.0, 178.0], [293.0, 188.0], [267.0, 189.0]'
# ...Line # 13 has text content 'I-T) 아메리카노' within bounding box '[91.0, 193.0], [161.0, 193.0], [161.0, 203.0], [91.0, 203.0]'
# ...Line # 14 has text content '4. 100' within bounding box '[197.0, 192.0], [223.0, 192.0], [223.0, 202.0], [197.0, 201.0]'
# ...Line # 15 has text content '2' within bounding box '[234.0, 192.0], [242.0, 192.0], [242.0, 201.0], [235.0, 200.0]'
# ...Line # 16 has text content '8,200' within bounding box '[267.0, 190.0], [294.0, 189.0], [294.0, 199.0], [267.0, 199.0]'
# ...Line # 17 has text content '합계' within bounding box '[91.0, 212.0], [111.0, 211.0], [111.0, 223.0], [91.0, 222.0]'
# ...Line # 18 has text content '12,700' within bounding box '[262.0, 209.0], [295.0, 209.0], [295.0, 219.0], [262.0, 219.0]'
# ...Line # 19 has text content '결제금액' within bounding box '[91.0, 231.0], [172.0, 231.0], [171.0, 244.0], [91.0, 243.0]'
# ...Line # 20 has text content '12, 700' within bounding box '[233.0, 230.0], [292.0, 228.0], [293.0, 239.0], [234.0, 242.0]'
# ...Line # 21 has text content '(부가세포함)' within bounding box '[90.0, 241.0], [153.0, 240.0], [153.0, 252.0], [90.0, 254.0]'
# ...Line # 22 has text content '(1, 154)' within bounding box '[258.0, 239.0], [293.0, 239.0], [293.0, 249.0], [259.0, 250.0]'
# ...Line # 23 has text content '카카오페이' within bounding box '[90.0, 262.0], [142.0, 262.0], [142.0, 274.0], [90.0, 273.0]'
# ...Line # 24 has text content '12, 700' within bounding box '[263.0, 260.0], [295.0, 259.0], [296.0, 269.0], [263.0, 270.0]'
# ...Line # 25 has text content '결제 수단 :' within bounding box '[90.0, 282.0], [157.0, 282.0], [157.0, 294.0], [90.0, 293.0]'
# ...Line # 26 has text content '카카오페이머니(머니)' within bounding box '[191.0, 280.0], [295.0, 278.0], [295.0, 290.0], [191.0, 292.0]'
# ...Line # 27 has text content '바코드 번호 : 281006 ************** 0800' within bounding box '[90.0, 292.0], [295.0, 289.0], [295.0, 300.0], [90.0, 303.0]'
# ...Line # 28 has text content '승인 번호 :' within bounding box '[90.0, 304.0], [153.0, 302.0], [153.0, 312.0], [91.0, 314.0]'
# ...Line # 29 has text content '29508878' within bounding box '[252.0, 301.0], [295.0, 300.0], [295.0, 310.0], [252.0, 311.0]'
# ...Line # 30 has text content '현금영수증 발급 500' within bounding box '[89.0, 322.0], [192.0, 323.0], [191.0, 340.0], [89.0, 338.0]'
# ...Line # 31 has text content '010 -****- 2995' within bounding box '[228.0, 320.0], [296.0, 320.0], [296.0, 330.0], [228.0, 331.0]'
# ...Line # 32 has text content '승인번호: 177263830' within bounding box '[202.0, 331.0], [296.0, 331.0], [296.0, 341.0], [202.0, 342.0]'
# ...Line # 33 has text content '현금영수증 문의 : 126-1-1' within bounding box '[125.0, 343.0], [254.0, 341.0], [255.0, 352.0], [125.0, 355.0]'
# ...Line # 34 has text content '결제수단 변경은 구입하신 매장에서' within bounding box '[106.0, 364.0], [275.0, 362.0], [275.0, 373.0], [106.0, 376.0]'
# ...Line # 35 has text content '가능하며, 반드시 구매 영수증과' within bounding box '[109.0, 375.0], [266.0, 373.0], [266.0, 383.0], [109.0, 386.0]'
# ...Line # 36 has text content '원거래 결제수단을 지참하셔야 합니다.' within bounding box '[93.0, 386.0], [279.0, 382.0], [279.0, 392.0], [94.0, 397.0]'
# ...Line # 37 has text content '(변경 가능 기간 : ~ 2021-08-25)' within bounding box '[115.0, 395.0], [274.0, 393.0], [274.0, 404.0], [115.0, 407.0]'
# ...Line # 38 has text content 'www. starbucks. co. kr' within bounding box '[140.0, 417.0], [240.0, 415.0], [240.0, 425.0], [140.0, 428.0]'
# ...Line # 39 has text content '*20130482101130749*' within bounding box '[140.0, 448.0], [241.0, 446.0], [241.0, 456.0], [140.0, 459.0]'
# ...Line # 40 has text content '본 영수증은 BPA Free 종이를 사용합니다.' within bounding box '[89.0, 460.0], [292.0, 455.0], [292.0, 468.0], [90.0, 473.0]'
# ...Line # 41 has text content '고객요청에의해 일회용컵이 제공되었습니다' within bounding box '[89.0, 481.0], [301.0, 477.0], [301.0, 490.0], [90.0, 494.0]'
# ...Word 'STARBUCKS' has a confidence of 0.965
# ...Word '현' has a confidence of 0.981
# ...Word '금' has a confidence of 0.995
# ...Word '(' has a confidence of 0.932
# ...Word '소' has a confidence of 0.995
# ...Word '득' has a confidence of 0.984
# ...Word '공' has a confidence of 0.99
# ...Word '제' has a confidence of 0.995
# ...Word ')' has a confidence of 0.993
# ...Word '화' has a confidence of 0.361
# ...Word '성' has a confidence of 0.99
# ...Word '시' has a confidence of 0.995
# ...Word '청' has a confidence of 0.839
# ...Word '점' has a confidence of 0.925
# ...Word 'T:1522-3232' has a confidence of 0.95
# ...Word '경' has a confidence of 0.98
# ...Word '기' has a confidence of 0.949
# ...Word '화' has a confidence of 0.995
# ...Word '성' has a confidence of 0.949
# ...Word '시' has a confidence of 0.99
# ...Word '청' has a confidence of 0.963
# ...Word '로' has a confidence of 0.995
# ...Word '113' has a confidence of 0.994
# ...Word '대' has a confidence of 0.994
# ...Word '표' has a confidence of 0.99
# ...Word ':' has a confidence of 0.988
# ...Word '충' has a confidence of 0.753
# ...Word '데' has a confidence of 0.995
# ...Word '이' has a confidence of 0.992
# ...Word '비' has a confidence of 0.991
# ...Word '드' has a confidence of 0.995
# ...Word '호' has a confidence of 0.99
# ...Word '선' has a confidence of 0.577
# ...Word '201-81-21515' has a confidence of 0.991
# ...Word '[' has a confidence of 0.992
# ...Word '매' has a confidence of 0.99
# ...Word '장' has a confidence of 0.928
# ...Word '#3794.' has a confidence of 0.684
# ...Word 'POS' has a confidence of 0.987
# ...Word '01]' has a confidence of 0.932
# ...Word '2021-08-11' has a confidence of 0.985
# ...Word '13:02:33' has a confidence of 0.991
# ...Word '주' has a confidence of 0.996
# ...Word '문' has a confidence of 0.995
# ...Word '번' has a confidence of 0.995
# ...Word '호' has a confidence of 0.997
# ...Word 'A-01' has a confidence of 0.982
# ...Word 'T)' has a confidence of 0.988
# ...Word '콜' has a confidence of 0.247
# ...Word '드' has a confidence of 0.993
# ...Word '브' has a confidence of 0.909
# ...Word '루' has a confidence of 0.911
# ...Word '4,500' has a confidence of 0.754
# ...Word '1' has a confidence of 0.995
# ...Word '4,500' has a confidence of 0.618
# ...Word 'I-T)' has a confidence of 0.921
# ...Word '아' has a confidence of 0.936
# ...Word '메' has a confidence of 0.744
# ...Word '리' has a confidence of 0.983
# ...Word '카' has a confidence of 0.996
# ...Word '노' has a confidence of 0.994
# ...Word '4.' has a confidence of 0.646
# ...Word '100' has a confidence of 0.995
# ...Word '2' has a confidence of 0.636
# ...Word '8,200' has a confidence of 0.612
# ...Word '합' has a confidence of 0.994
# ...Word '계' has a confidence of 0.988
# ...Word '12,700' has a confidence of 0.774
# ...Word '결' has a confidence of 0.875
# ...Word '제' has a confidence of 0.991
# ...Word '금' has a confidence of 0.911
# ...Word '액' has a confidence of 0.996
# ...Word '12,' has a confidence of 0.993
# ...Word '700' has a confidence of 0.994
# ...Word '(' has a confidence of 0.988
# ...Word '부' has a confidence of 0.996
# ...Word '가' has a confidence of 0.995
# ...Word '세' has a confidence of 0.995
# ...Word '포' has a confidence of 0.995
# ...Word '함' has a confidence of 0.987
# ...Word ')' has a confidence of 0.987
# ...Word '(1,' has a confidence of 0.75
# ...Word '154)' has a confidence of 0.988
# ...Word '카' has a confidence of 0.995
# ...Word '카' has a confidence of 0.995
# ...Word '오' has a confidence of 0.992
# ...Word '페' has a confidence of 0.995
# ...Word '이' has a confidence of 0.99
# ...Word '12,' has a confidence of 0.995
# ...Word '700' has a confidence of 0.996
# ...Word '결' has a confidence of 0.995
# ...Word '제' has a confidence of 0.995
# ...Word '수' has a confidence of 0.991
# ...Word '단' has a confidence of 0.996
# ...Word ':' has a confidence of 0.917
# ...Word '카' has a confidence of 0.995
# ...Word '카' has a confidence of 0.996
# ...Word '오' has a confidence of 0.993
# ...Word '페' has a confidence of 0.993
# ...Word '이' has a confidence of 0.992
# ...Word '머' has a confidence of 0.995
# ...Word '니' has a confidence of 0.992
# ...Word '(' has a confidence of 0.987
# ...Word '머' has a confidence of 0.992
# ...Word '니' has a confidence of 0.993
# ...Word ')' has a confidence of 0.992
# ...Word '바' has a confidence of 0.987
# ...Word '코' has a confidence of 0.995
# ...Word '드' has a confidence of 0.988
# ...Word '번' has a confidence of 0.989
# ...Word '호' has a confidence of 0.998
# ...Word ':' has a confidence of 0.957
# ...Word '281006' has a confidence of 0.942
# ...Word '**************' has a confidence of 0.928
# ...Word '0800' has a confidence of 0.929
# ...Word '승' has a confidence of 0.972
# ...Word '인' has a confidence of 0.987
# ...Word '번' has a confidence of 0.992
# ...Word '호' has a confidence of 0.996
# ...Word ':' has a confidence of 0.988
# ...Word '29508878' has a confidence of 0.961
# ...Word '현' has a confidence of 0.994
# ...Word '금' has a confidence of 0.874
# ...Word '영' has a confidence of 0.77
# ...Word '수' has a confidence of 0.995
# ...Word '증' has a confidence of 0.945
# ...Word '발' has a confidence of 0.859
# ...Word '급' has a confidence of 0.207
# ...Word '500' has a confidence of 0.465
# ...Word '010' has a confidence of 0.995
# ...Word '-****-' has a confidence of 0.945
# ...Word '2995' has a confidence of 0.982
# ...Word '승' has a confidence of 0.91
# ...Word '인' has a confidence of 0.994
# ...Word '번' has a confidence of 0.987
# ...Word '호' has a confidence of 0.992
# ...Word ':' has a confidence of 0.992
# ...Word '177263830' has a confidence of 0.978
# ...Word '현' has a confidence of 0.995
# ...Word '금' has a confidence of 0.993
# ...Word '영' has a confidence of 0.347
# ...Word '수' has a confidence of 0.992
# ...Word '증' has a confidence of 0.971
# ...Word '문' has a confidence of 0.994
# ...Word '의' has a confidence of 0.352
# ...Word ':' has a confidence of 0.993
# ...Word '126-1-1' has a confidence of 0.99
# ...Word '결' has a confidence of 0.988
# ...Word '제' has a confidence of 0.847
# ...Word '수' has a confidence of 0.995
# ...Word '단' has a confidence of 0.995
# ...Word '변' has a confidence of 0.99
# ...Word '경' has a confidence of 0.969
# ...Word '은' has a confidence of 0.993
# ...Word '구' has a confidence of 0.994
# ...Word '입' has a confidence of 0.995
# ...Word '하' has a confidence of 0.993
# ...Word '신' has a confidence of 0.991
# ...Word '매' has a confidence of 0.992
# ...Word '장' has a confidence of 0.995
# ...Word '에' has a confidence of 0.994
# ...Word '서' has a confidence of 0.988
# ...Word '가' has a confidence of 0.967
# ...Word '능' has a confidence of 0.996
# ...Word '하' has a confidence of 0.991
# ...Word '며' has a confidence of 0.995
# ...Word ',' has a confidence of 0.959
# ...Word '반' has a confidence of 0.994
# ...Word '드' has a confidence of 0.996
# ...Word '시' has a confidence of 0.991
# ...Word '구' has a confidence of 0.993
# ...Word '매' has a confidence of 0.995
# ...Word '영' has a confidence of 0.991
# ...Word '수' has a confidence of 0.993
# ...Word '증' has a confidence of 0.816
# ...Word '과' has a confidence of 0.994
# ...Word '원' has a confidence of 0.997
# ...Word '거' has a confidence of 0.995
# ...Word '래' has a confidence of 0.996
# ...Word '결' has a confidence of 0.978
# ...Word '제' has a confidence of 0.99
# ...Word '수' has a confidence of 0.995
# ...Word '단' has a confidence of 0.995
# ...Word '을' has a confidence of 0.992
# ...Word '지' has a confidence of 0.995
# ...Word '참' has a confidence of 0.995
# ...Word '하' has a confidence of 0.995
# ...Word '셔' has a confidence of 0.214
# ...Word '야' has a confidence of 0.995
# ...Word '합' has a confidence of 0.987
# ...Word '니' has a confidence of 0.995
# ...Word '다' has a confidence of 0.349
# ...Word '.' has a confidence of 0.775
# ...Word '(' has a confidence of 1.0
# ...Word '변' has a confidence of 1.0
# ...Word '경' has a confidence of 0.999
# ...Word '가' has a confidence of 1.0
# ...Word '능' has a confidence of 0.999
# ...Word '기' has a confidence of 1.0
# ...Word '간' has a confidence of 1.0
# ...Word ':' has a confidence of 1.0
# ...Word '~' has a confidence of 1.0
# ...Word '2021-08-25)' has a confidence of 1.0
# ...Word 'www.' has a confidence of 0.689
# ...Word 'starbucks.' has a confidence of 0.982
# ...Word 'co.' has a confidence of 0.995
# ...Word 'kr' has a confidence of 0.994
# ...Word '*20130482101130749*' has a confidence of 0.937
# ...Word '본' has a confidence of 0.995
# ...Word '영' has a confidence of 0.991
# ...Word '수' has a confidence of 0.996
# ...Word '증' has a confidence of 0.974
# ...Word '은' has a confidence of 0.993
# ...Word 'BPA' has a confidence of 0.99
# ...Word 'Free' has a confidence of 0.988
# ...Word '종' has a confidence of 0.93
# ...Word '이' has a confidence of 0.995
# ...Word '를' has a confidence of 0.982
# ...Word '사' has a confidence of 0.995
# ...Word '용' has a confidence of 0.995
# ...Word '합' has a confidence of 0.995
# ...Word '니' has a confidence of 0.993
# ...Word '다' has a confidence of 0.996
# ...Word '.' has a confidence of 0.995
# ...Word '고' has a confidence of 0.99
# ...Word '객' has a confidence of 0.995
# ...Word '요' has a confidence of 0.995
# ...Word '청' has a confidence of 0.993
# ...Word '에' has a confidence of 0.984
# ...Word '의' has a confidence of 0.878
# ...Word '해' has a confidence of 0.995
# ...Word '일' has a confidence of 0.995
# ...Word '회' has a confidence of 0.992
# ...Word '용' has a confidence of 0.995
# ...Word '컵' has a confidence of 0.971
# ...Word '이' has a confidence of 0.991
# ...Word '제' has a confidence of 0.991
# ...Word '공' has a confidence of 0.982
# ...Word '되' has a confidence of 0.995
# ...Word '었' has a confidence of 0.995
# ...Word '습' has a confidence of 0.995
# ...Word '니' has a confidence of 0.995
# ...Word '다' has a confidence of 0.995
# ----------------------------------------
