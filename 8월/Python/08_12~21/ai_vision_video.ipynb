# %%
# index 만들기 
import requests

index_name = "1507-ms-spanish"

def create_video_index():
    
    endpoint = f"https://1507-computervision-we.cognitiveservices.azure.com/computervision/retrieval/indexes/{index_name}?api-version=2023-05-01-preview"
    api_key = "450e09da0b934eb2bc950eb9f51fa754"

    headers = {
        "Ocp-Apim-Subscription-Key": api_key,
        "Content-Type": "application/json"
    }

    data = {
        "metadataSchema": {
            "fields": [
                {
                    "name": "cameraId",
                    "searchable": False,
                    "filterable": True,
                    "type": "string"
                },
                {
                    "name": "timestamp",
                    "searchable": False,
                    "filterable": True,
                    "type": "datetime"
                }
            ]
        },
        "features": [
            {
                "name": "vision",
                "domain": "surveillance"
            },
            {
                "name": "speech"
            }
        ]
    }

    response = requests.put(endpoint, headers=headers, json=data)
    
    if 200 <= response.status_code <= 300:
        return response.json()
    else:
        return None
    
print(create_video_index())
# Out:
# None

# %%
# 인덱스로 비디오 파일 추가 

import requests  
  
endpoint = f"https://1507-computervision-we.cognitiveservices.azure.com/computervision/retrieval/indexes/{index_name}/ingestions/my-ingestion?api-version=2023-05-01-preview"  
api_key = "450e09da0b934eb2bc950eb9f51fa754"  
  
headers = {  
    "Ocp-Apim-Subscription-Key": api_key,  
    "Content-Type": "application/json"  
}  
  
data = {  
  "videos": [  
    {  
      "mode": "add",  
      "documentId": "02a504c9cd28296a8b74394ed7488045",  
      "documentUrl": "https://1507aistorage.blob.core.windows.net/video-test/Spanish.mp4?sp=r&st=2024-08-13T06:13:31Z&se=2024-08-16T14:13:31Z&spr=https&sv=2022-11-02&sr=b&sig=WVB3E25jv%2FeiMpSPx0RnCMEKtoI0AiJVUDrZGJKJCbo%3D",  
      "metadata": {  
        "cameraId": "camera1",  
        "timestamp": "2023-06-30 17:40:33"  
      }  
    }
  ]  
}  
  
response = requests.put(endpoint, headers=headers, json=data)  
print(response)  
if 200 <= response.status_code <= 300:  
    
    print("Videos submitted for indexing.")  
else:  
    print("Error submitting videos for indexing.")
# Out:
# <Response [202]>
# Videos submitted for indexing.

# %%
# 수집 완료 대기

import requests  
  
endpoint = f"https://1507-computervision-we.cognitiveservices.azure.com/computervision/retrieval/indexes/{index_name}/ingestions"  
api_key = "450e09da0b934eb2bc950eb9f51fa754"  
  
params = {  
    "api-version": "2023-05-01-preview",  
    "$top": 20  
}  
  
headers = {  
    "ocp-apim-subscription-key": api_key  
}  
  
response = requests.get(endpoint, headers=headers, params=params)  
  
if response.status_code == 200:  
    import json
    print(json.dumps(response.json(), indent=2))  
else:  
    print("Error retrieving video index ingestions.")
# Out:
# {
#   "value": [
#     {
#       "name": "my-ingestion",
#       "state": "Completed",
#       "batchName": "59ee5dab-7146-4cbd-ae84-49b03383c2a4",
#       "createdDateTime": "2024-08-13T06:16:23.5368079Z",
#       "lastModifiedDateTime": "2024-08-13T06:17:24.0524660Z"
#     }
#   ]
# }

# %%
# 인덱스로 비디오 파일 추가 정보를 추출.

import requests  
  
endpoint = f"https://1507-computervision-we.cognitiveservices.azure.com/computervision/retrieval/indexes/{index_name}:queryByText?api-version=2023-05-01-preview"  
api_key = "450e09da0b934eb2bc950eb9f51fa754"  
  
headers = {  
    "Ocp-Apim-Subscription-Key": api_key,  
    "Content-Type": "application/json"  
}  
  
data = {
  'queryText': 'diver ',
  'filters': {
    'stringFilters': [
      {
        'fieldName': 'cameraId',
        'values': [
          'camera1'
        ]
      }
    ],
    'featureFilters': ['vision']
  }
} 
  
response = requests.post(endpoint, headers=headers, json=data)  
print(response)  
if response.status_code == 200:  
    import json
    print(json.dumps(response.json(), indent=2))  
    print("Videos submitted for indexing.")  
else:  
    print("Error submitting videos for indexing.")
# Out:
# <Response [200]>
# {
#   "value": [
#     {
#       "documentId": "02a504c9cd28296a8b74394ed7488045",
#       "documentKind": "VideoInterval",
#       "start": "00:00:30.0300000",
#       "end": "00:00:32.0320000",
#       "best": "00:00:30.0300000",
#       "relevance": 0.21509969234466553
#     },
#     {
#       "documentId": "02a504c9cd28296a8b74394ed7488045",
#       "documentKind": "VideoInterval",
#       "start": "00:00:12.0120000",
#       "end": "00:00:19.0190000",
#       "best": "00:00:16.0160000",
#       "relevance": 0.2031128853559494
#     },
#     {
#       "documentId": "02a504c9cd28296a8b74394ed7488045",
#       "documentKind": "VideoInterval",
#       "start": "00:00:00",
#       "end": "00:00:05.0050000",
#       "best": "00:00:00",
#       "relevance": 0.19093871116638184
#     },
#     {
#       "documentId": "02a504c9cd28296a8b74394ed7488045",
#       "documentKind": "VideoInterval",
#       "start": "00:00:22.0220000",
#       "end": "00:00:30.0300000",
# ...
